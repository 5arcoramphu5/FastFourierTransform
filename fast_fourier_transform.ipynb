# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import data
import time

# %%
plt.style.use('ggplot')
colors = ["tomato", "dodgerblue", "yellow","yellowgreen", "mediumorchid"]
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=colors)

# %% [markdown]
# # Jednowymiarowa FFT

# %% [markdown]
# ## Wykres DFT przykładowej funkcji (używając np.fft)

# %%
# funkja zwracająca próbki podanej funkcji
def samples(f, samplingRate):
    X = np.linspace(0, 2*np.pi, samplingRate)
    a = np.array([f(x) for x in X])
    return (a, X)

# %%
# pary (częstotliwość, mnożnik)
sineComponents = [ (1, 3), (4, 1), (7, 0.5), (9, 0.3) ]

def f(t):
    value = 0
    for (freq, mul) in sineComponents:
        value += mul*np.sin(freq*t)
    return value

a, x = samples(f, 256)
aDraw, xDraw = samples(f, 2048)
A = np.fft.fft(a)
freq = np.arange(len(a))

plt.figure(figsize = (20, 4))

plt.subplot(141)
plt.title("Wykres funkcji f i jej próbek")
plt.plot(xDraw, aDraw)
plt.plot(x, a, 'o', markersize=3)

plt.subplot(142)
plt.title("Wynik DFT (wartość bezwzględna)")
plt.stem(freq, np.abs(A), basefmt="-b")
plt.xlim(0, 10)

plt.subplot(143)
plt.title("Wynik DFT (argument)")
plt.stem(freq, np.angle(A), basefmt="-b")
plt.ylim(-np.pi, np.pi)
plt.xlim(0, 10)

plt.subplot(144)
plt.title("Wynik odwrotnej DFT, a wykres f")
plt.plot(xDraw, aDraw)
plt.plot(x, np.real(np.fft.ifft(A)), 'o', markersize=3)

plt.show()

# %% [markdown]
# ## Implementacja FFT (Cooley-Tukey Radix 2-DIT)

# %%
def fft(a):
    
    if(len(a) == 1):
        return np.array(a)
    
    even = a[::2]
    odd = a[1::2]
    E = fft(even)
    O = fft(odd)
    
    dft1 = E  + np.exp(-2*np.pi*1j/len(a)*np.arange(len(a)/2)) * O
    dft2 = E - np.exp(-2*np.pi*1j/len(a)*np.arange(len(a)/2)) * O

    return np.concatenate( (dft1, dft2) )

# %%
def swapImRe(x):
    return np.imag(x) + 1j*np.real(x)

def ifft(A):
    a = swapImRe(A)
    a = fft(a)
    a = swapImRe(a)
    a /= len(a)
    return a

# %%
A = fft(a)

plt.figure(figsize = (9, 3))
plt.subplot(121)
plt.title("Wynik zaimplementowanej FFT")
plt.stem(freq, np.abs(A), basefmt="-b")
plt.xlim(0, 10)

plt.subplot(122)
plt.title("Wynik zaimplementowanej IDFT")
plt.plot(x, np.real(ifft(A)))

plt.show()

# %% [markdown]
# ## Porównanie czasów wykonania z obliczaniem z definicji

# %%
def dft(a):
    omega = np.exp(1j* 2* np.pi / len(a))
    return [ np.sum(a * omega**(-k * np.arange(len(a)) )) for k in np.arange(len(a))]

# %%
A = dft(a)

plt.figure(figsize = (4, 4))
plt.title("Wynik DFT z definicji")
plt.stem(freq, np.abs(A), basefmt="-b")
plt.xlim(0, 10)

plt.show()

# %%
a, x = samples(f, 2048)

start = time.process_time()
fft(a)
end = time.process_time()
print("FFT:", end-start, "sekundy")

start = time.process_time()
dft(a)
end = time.process_time()
print("Z definicji:", end-start, "sekundy")
# Out:
# FFT: 0.08015852900000198 sekundy
# Z definicji: 2.633160687 sekundy

# %% [markdown]
# # Wielowymiarowa FFT

# %% [markdown]
# ## Wykresy funkcji postaci $e^{ixk_1} e^{ix k_2}$

# %%
n = 5

fig, axes = plt.subplots(nrows=n, ncols=n, figsize=(5, 5))

canvasSize = 64
x = np.arange(canvasSize)
X, Y = np.meshgrid(x, x)

for k1 in range(0, n):
    for k2 in range(0, n):
        baseVector = np.real( np.exp( 1j*k1*X / canvasSize * 2 * np.pi ) * np.exp( 1j*k2*Y / canvasSize * 2 * np.pi) )
        axes[k1, k2].imshow(baseVector, vmin=-1, vmax=1)

for axs in axes:
    for ax in axs:
        ax.set_xticks([])
        ax.set_yticks([])

for i in range(n):
    axes[0, i].set_title('k1='+str(i), fontsize=10)
    axes[i, 0].set_ylabel('k2='+str(i), fontsize=10)

plt.subplots_adjust(wspace=0.05, hspace=0.05)
plt.show()

# %% [markdown]
# ## Wykres DFT przykładowej funkcji (z użyciem np.fft)

# %%
def f(x, y, canvasSize):
    k1 = 3
    k2 = 2
    k3 = 30
    k4 = 3
    value = np.exp(1j * x * k1 * 2 * np.pi / canvasSize) * np.exp(1j * y * k2 * 2 * np.pi / canvasSize)
    value = value + np.exp(1j * x * k3 * 2 * np.pi / canvasSize) * np.exp(1j * y * k4 * 2 * np.pi / canvasSize)
    return value

canvasSize = 32
x = np.arange(canvasSize)
X, Y = np.meshgrid(x, x)
a = f(X, Y, canvasSize)

plt.figure(figsize=(6,8))
plt.set_cmap("gray")

plt.subplot(121)
plt.title('Wykres części rzeczywistej funkcji f')
plt.imshow(np.real(a))
plt.grid(False)

plt.subplot(122)
plt.title('Wykres DFT')
A = np.fft.fft2(a)
plt.imshow(np.abs(A))
plt.grid(False)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Implementacja 2D FFT

# %% [markdown]
# ### Wersja "row-column"

# %%
def row_columnFFT(a):
    
    A = np.array(a, dtype=np.complex128)
    for i in range(len(A)):
        row = A[i]
        A[i] = fft(row)

    A = A.T
    for i in range(len(A)):
        col = A[i]
        A[i] = fft(col)
    A = A.T
    return A

# %%
canvasSize = 32
x = np.arange(canvasSize)
X, Y = np.meshgrid(x, x)
a = f(X, Y, canvasSize)

plt.figure(figsize=(4,4))
plt.set_cmap("gray")

plt.subplot(122)
plt.title('Wykres zaimplementowanej FFT')
A = row_columnFFT(a)
plt.imshow(np.abs(A))
plt.grid(False)

plt.tight_layout()

plt.show()

# %% [markdown]
# ### Wersja "vector-radix"

# %%
def omega(N):
    return np.exp(2*np.pi*1j / N)

def vector_radixFFT(a):

    if a.shape == (1,1):
        return a
    
    N1, N2 = a.shape
    halfN1 = int(N1/2)
    halfN2 = int(N2/2)

    partDFT = np.empty( (2,2) )
    for q1 in range(2):
        for q2 in range(2):
            subsequence = a[q1::2, q2::2]
            partDFT[q1][q2] = vector_radixFFT(subsequence)

    u1 = np.arange(halfN1).reshape(halfN1, 1)
    u2 = np.arange(halfN2).reshape(1, halfN2)
    partDFT[0][1] = partDFT[0][1] * omega(N2)**u2
    partDFT[1][0] = partDFT[1][0] * omega(N1)**u1 
    partDFT[1][1] = partDFT[1][1] * omega(N1)**u1*omega(N2)**u2

    DFT = np.empty((N1, N2), dtype=np.complex128)
    DFT[ 0 : halfN1, 0 : halfN2 ] =  partDFT[0][0] + partDFT[0][1] + partDFT[1][0] + partDFT[1][1]
    DFT[ halfN1 : N1, 0 : halfN2] = partDFT[0][0] + partDFT[0][1] - partDFT[1][0] - partDFT[1][1]
    DFT[ 0 : halfN1, halfN2 : N2] = partDFT[0][0] - partDFT[0][1] + partDFT[1][0] - partDFT[1][1]
    DFT[ halfN1 : N1, halfN2 : N2] = partDFT[0][0] - partDFT[0][1] - partDFT[1][0] + partDFT[1][1]

    return DFT

# %%
canvasSize = 32

x = np.arange(canvasSize)
X, Y = np.meshgrid(x, x)
a = f(X, Y, canvasSize)

plt.figure(figsize=(4,4))
plt.set_cmap("gray")

plt.subplot(122)
plt.title('Wykres zaimplementowanej FFT')
A = row_columnFFT(a)
plt.imshow(np.abs(A))
plt.grid(False)

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Porównanie czasów metod obliczania 2D FFT

# %%
def dft2D(a):
    N1 = a.shape[0]
    N2 = a.shape[1]
    A = np.zeros(a.shape, dtype=np.complex128)

    for k1 in range(N1):
        for k2 in range(N2):
            for n1 in range(N1):
                for n2 in range(N2):
                    A[k1, k2] += a[n1, n2] * omega(N1)**(-k1*n1) * omega(N2)**(-k2*n2)

    return A

# %%
canvasSize = 32

x = np.arange(canvasSize)
X, Y = np.meshgrid(x, x)
a = f(X, Y, canvasSize)

plt.figure(figsize=(4,4))
plt.set_cmap("gray")

plt.subplot(122)
plt.title('Wykres DFT z definicji')
A = dft2D(a)
plt.imshow(np.abs(A))
plt.grid(False)

plt.tight_layout()

plt.show()

# %%
canvasSize = 32
x = np.arange(canvasSize)
X, Y = np.meshgrid(x, x)
a = f(X, Y, canvasSize)

start = time.process_time()
dft2D(a)
end = time.process_time()
print("Z definicji:", end-start, "sekundy")

start = time.process_time()
row_columnFFT(a)
end = time.process_time()
print("Row-column:", end-start, "sekundy")

start = time.process_time()
vector_radixFFT(a)
end = time.process_time()
print("Vector-radix:", end-start, "sekundy")
# Out:
# Z definicji: 9.858511204999985 sekundy
# Row-column: 0.06887593599998354 sekundy
# Vector-radix: 0.030879343000009385 sekundy

# %%
canvasSize = 1024
x = np.arange(canvasSize)
X, Y = np.meshgrid(x, x)
a = f(X, Y, canvasSize)

start = time.process_time()
row_columnFFT(a)
end = time.process_time()
print("Row-column:", end-start, "sekundy")

start = time.process_time()
vector_radixFFT(a)
end = time.process_time()
print("Vector-radix:", end-start, "sekundy")
# Out:
# Row-column: 74.921213618 sekundy
# Vector-radix: 32.930432061999966 sekundy

# %% [markdown]
# ## Kompresja obrazów za pomocą FFT

# %%
def compress(image, threshold):
    A = np.fft.fft2(image)
    A[np.abs(A) <= threshold] = 0

    zeroed = (np.abs(A) <= threshold).sum()
    N = A.shape[0]*A.shape[1]
    print('Wyzerowane: ', zeroed, 'z', N, ', czyli', float(zeroed)/N*100, '%')

    A = np.fft.ifft2(A)
    return np.real(A)

# %%
camera = data.camera()

plt.figure(figsize=(15, 30))

plt.subplot(131)
plt.title('Obraz oryginalny')
plt.imshow(camera, cmap='gray', interpolation='nearest')
plt.axis('off')

plt.subplot(132)
plt.title('Obraz po usunięciu 66% wartości DFT')
plt.imshow(compress(camera, 5000))
plt.axis('off')

plt.subplot(133)
plt.title('Obraz po usunięciu 95% wartości DFT')
plt.imshow(compress(camera, 20000))
plt.axis('off')

plt.show()
# Out:
# Wyzerowane:  172751 z 262144 , czyli 65.89927673339844 %
# Wyzerowane:  250445 z 262144 , czyli 95.53718566894531 %
